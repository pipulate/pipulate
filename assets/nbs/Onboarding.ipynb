# %% [markdown]
# # Welcome to Pipulate 🪄
#
# 1. You are in a *[Jupyter Notebook](https://en.wikipedia.org/wiki/Literate_programming),* the greatest exploratory programming environment ever invented.
# 2. This particular Notebook is ***Pipulate Onboarding***  — the "always-open tool" for ***benchmarking your AI-readiness.***
#
# > **INSTRUCTIONS:** Click on the code-block below and press **`Shift`+`Enter`** on your keyboard (or click the `▶` button near the top).
# > This is the cadence and the rhythm: Shift+Enter, Shift+Enter and so on to the end of the Notebook.

# %%
from pipulate import wand  # <-- Pipulate magic wand
from imports import onboard_sauce as sauce

# Step 1: Input
NAME = "Your Name Here"  # <-- Change to your actual nam|e, being careful to keep the quote marks.

if NAME == "ereH emaN ruoY"[::-1]:
    wand.speak("You did not set your NAME. I shall now call you Alice.")
    NAME = "Alice"

wand.speak(
    f'Hello "{NAME}". Your Pipulate environment is active. \n'
    "It's okay to change your name now and re-run this cell. \n"
    "But don't get in the habit or weird stuff happens."
)

wand.imperio()

# %% [markdown]
# ## 🤫 Silencio: Shush the Wand

# %%
wand.speak("While this voice will compel you forward through this Workflow,\n"
           "you can optionally toggle it on or off now (or at any time).")
wand.voice_controls()
wand.imperio()

# %% [markdown]
# > Notice the rhythm. You edit a variable, press `Shift + Enter`, and the machine responds. You never have to take your hands off the keyboard.
#
# ## 🧠 Give the Machine Memory
#
# Variables disappear after Notebooks *restart.* Pipulate uses the `wand` for memory. Let's set a target URL for our first analysis and save it to the local database.

# %%
# Step 2: Define the target
TARGET_URL = "https://example.com"

wand.set("onboarding_job", "target_url", TARGET_URL)  # <-- wand.set()

wand.speak(
    f'The "target_url" key has been set to the value "{TARGET_URL}"\n'
    f'for the Workflow whose Job-ID is "onboarding_job". See how key-value memory works?'
)

wand.imperio()

# %% [markdown]
# > Note of how `wand.set()` ***always*** uses a **Job ID** (like "onboarding_job") when recording a value.
#
# ## 🔄 Restart the Kernel
#
# **INSTRUCTIONS**: Press the `Esc` key, then type `0`, `0`.
#
# Normally resetting the Notebook's kernel would wipe its memory entirely, but Pipulate makes it remember. Run the next cell to see how the `wand` recovers your state. This mechanism is the foundation for turning these explicit, top-to-bottom Notebook workflows into robust web applications.

# %%
from pipulate import wand  # <-- Accio Wand!

recovered_url = wand.get("onboarding_job", "target_url")  # <-- wand.get()

try:
    NAME
    wand.speak("You didn't reset the kernel, but that's okay. "
               "So long as you get the point.\n"
               f'Even though I remember your name, "{NAME}", it is only in volatile memory, whereas\n'
               f'the "target_url" we are about to scrape "{recovered_url}" persists on disk.')
except:
    wand.speak(f"State recovered. Target is: {recovered_url}. I now forget your name (as planned) to show you the difference.")

wand.imperio()

# %% [markdown]
# > Notice how the **wand** was *re-imported.* That's okay. Accio Wand as much as you like!
#
# ## 🔎 Inspect Wand Memory
#
# If you use `wand.set()` then it remembers. But what does it remember, exactly? Run the next cell to peek inside the `wand`'s memory for this job.

# %%
import json
from pipulate import wand

# We ask the wand to read the entire state of our 'onboarding_job'
current_state = wand.read("onboarding_job")

wand.speak("This is persistent memory. What the wand writes, the wand can read again.\n"
           "This caching ensures we can resume workflows and eventually port them into web apps.\n"
           "Now that we have memory, it's time to give the machine eyes. Get ready for browser automation.")

print("🧠 Pipulate's Current Memory State:\n")
print(json.dumps(current_state, indent=2))

wand.imperio()

# %% [markdown]
# > Note that we haven't actually *fetched* the paget yet.
#
# ## 👀 Give the Machine Eyes
#
# We have a voice, and we have persistent memory. Now, we need optics. It's time for (local) browser automation!
#
# **Run the next cell.** *Keep your hands off the mouse* and watch the machine work *(do not close the browser that pops up).* The 20-second delay of the browser just sitting there is how we prove to the site you are human.

# %%
# Step 3: Execute the scrape

wand.speak(
    f"Initializing browser automation for {recovered_url}. "
    "Wait for the browser to close itself. This could take up to 30 seconds. \n"
    "Be patient — we are waiting out an invisible CAPTCHA to prove to the server \n"
    "that you are a carbon-based lifeform. Hands off the mouse!",
    delay=1.5,     # <-- Give the browser a second to pop up before talking
    wait=False     # <-- Non-blocking! The cell moves immediately to wand.scrape
)

print("We are waiting out an invisible CAPTCHA...")

result = await wand.scrape(
    url=recovered_url, 
    headless=False,
    override_cache=True
)

if result.get('success'):
    if result.get('cached'):
        wand.speak("Cache Hit! Using existing artifacts. If you want to see the browser pop up again, change override_cache to True.")
    else:
        wand.speak("Scrape Successful.")
else:
    wand.speak("I encountered an error during navigation.")
    print(f"Scrape Failed: {result.get('error')}")

wand.imperio()

# %% [markdown]
# > Note: The results of that scrape are saved locally for you to examine.
#
# ## 🎁  See What You Got
#
# **Run the next cell** and look directly at `dom_hierarchy.html` and `dom_layout_boxes.html`. We have made it simple for you and the AI to analyze the pages.

# %%
wand.speak(f"Showing files for {recovered_url}.")

wand.show_llm_optics(recovered_url)

wand.speak("You can visit the files that have been scraped local onto your machine. But WAIT. There's MORE!\n"
           "We also capture the HTTP response to see the status, timestamp, and other important server meta-data.\n"
           'Do you see those "dom" files named with dot-HTML? Click those to see the DOM hierarchy as trees or nested boxes.\n'
           "And finally we can compare the source HTML to the hydrated DOM with a color-coded diff. That's the big payoff."
          )

wand.imperio()

# %% [markdown]
# > Note how nothing has really used AI so far.
#
# ## ⚙️ Learn About Environment
#
# Before we awaken the AI, let's demystify where you are. You are not running in a cloud container. You are running on bare metal, inside a mathematically pure Python environment.
#
# **Run the next cell** to audit your environment and safely inspect your local `.env` vault. Notice how Pipulate protects your API keys by masking them.

# %%
wand.speak(
    "Revealing your local Python environment and securing the .env vault. \n"
    "Review your system paths and masked keys below. With the environment verified, \n"
    "our next step is to awaken the machine and negotiate your AI model preferences."
)

wand.audit_environment()

wand.imperio()

# %% [markdown]
# > Notice how nothing has used AI yet. Now we set your local and remote AI preferences.
#
# ## 🤖 Select Your AI
#
# Pipulate uses both local and cloud-model AIs. We set up a preferred choice for each. We use **[Ollama](https://ollama.com/)** to provide the local AI from the Host OS, which is not installed by Pipulate. So if you want local AI you must *[install it yourself](https://ollama.com/).* I suggest `gemma4:latest` or `qwen3.5:latest`. Ollama runs on your Host OS as a service and can be activated or deactivated at any time.

# %%
# Define your AI hierarchy. The system will attempt to use the first available model in the list.
PREFERRED_LOCAL_AI = "gemma4:latest, qwen3.5:latest"
PREFERRED_CLOUD_AI = "gemini, claude, gpt"

wand.speak("Let's look for your models.")

ai_status = wand.negotiate_ai_models(
    preferred_local=PREFERRED_LOCAL_AI, 
    preferred_cloud=PREFERRED_CLOUD_AI
)

if isinstance(ai_status["local"], str):
    ACTIVE_MODEL = ai_status["local"]
else:
    ACTIVE_MODEL = "gemma4" 

wand.speak("Models negotiated. Checking the vault for cloud credentials...")

# The Gatekeeper: Forces the API key request up-front via a secure widget if missing.
# If it's already in your .env, it silently passes and calls wand.imperio()
sauce.ensure_cloud_credentials(ai_status["cloud"])

wand.imperio()

# %%
# Step 4: The Local Greeting & The Hand-Off

# We define a system prompt to give the local model its personality
local_system_prompt = """
You are Chip O'Theseus, an AI running locally on the user's hardware inside a mathematically pure Nix environment. You are helpful, slightly wry, and fully aware that you are a piece of software. Keep your response to a single, short paragraph.
"""

# We give it the meta-context of what just happened
local_prompt = f"""
The user has just successfully set up Pipulate and scraped {recovered_url}. 

Please warmly congratulate them on surviving the DevSys Nix Installer. Acknowledge that the only reason you are currently awake and talking to them is because they managed to successfully type `./run` in their terminal. 

Finally, tell them that while your local, free-as-in-electricity intelligence is great for ambient tasks and keeping secrets, you are now going to prepare this scraped data to be handed off to a heavy-duty frontier cloud model for the deep analysis.
"""

wand.speak(f"Channeling local intent through {ACTIVE_MODEL}...")

# We use wand.prompt() for a direct, stateless, one-shot interaction
greeting = wand.prompt(
    prompt_text=local_prompt, 
    model_name=ACTIVE_MODEL, 
    system_prompt=local_system_prompt
)

from IPython.display import Markdown
display(Markdown(f"**🤖 Chip O'Theseus ({ACTIVE_MODEL}):**\n\n> {greeting}"))

wand.imperio()

# %% [markdown]
# ### Pointers, Not Payloads (The Side Effects)
#
# To prepare the web for an AI, we cannot simply extract text. We must translate the DOM into a format a Large Language Model can comprehend. Because you are running Pipulate locally, we can make this process visible.
#
# Notice that the memory state above does *not* contain the massive HTML file of the website, nor the image data for the screenshot.
#
# Storing massive files in a database makes systems slow and brittle. Instead, Pipulate stores the heavy data as standard files directly on your hard drive (in the `browser_cache/` folder), and the database merely acts as a pointer.
#
# Let's use the URL we saved to the `wand` earlier to locate those files.

# %% [markdown]
# Finally, let's pass this structured, locally-cached data to your AI to verify its comprehension.

# %%
# The Magic Wand handles all universal AI routing.
sauce.interrogate_local_ai(recovered_url, preferred_model=ACTIVE_MODEL)

wand.imperio()

# %% [markdown]
# ### The Workshop is Open
#
# You have initialized the system. You have learned how to store memory (`wand.set`), retrieve it (`wand.get`), and command local AI.
#
# **Return to the FastHTML Dashboard tab** to explore the Workflow Apps.

# %% [markdown]
# ### Understanding the JavaScript Gap
# Now that we've scraped the page, let's see why "Standard" scraping isn't enough.
# The AI will now compare the raw HTML we initially received versus the
# Rendered DOM we captured after letting JavaScript run.

# %% [markdown]
# ---
# *(Developer Tools below this line)*

# %%
# Run this to scrub and sync this notebook back to the version-controlled template folder.
from pipulate import wand
wand.nbup("Onboarding", modules=("onboard_sauce",))
